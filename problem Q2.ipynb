# %% [markdown]
# # Problelm sakurai
# ![image.png](attachment:image.png)

# %% [markdown]
# # Zettili
# ![image.png](attachment:image.png)

# %% [markdown]
# # Zettili
# ![image.png](attachment:image.png)

# %% [markdown]
# # Griffith Example 6.1(452 page)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exmaple 9.1 zettlie ![image.png](attachment:image.png)

# %% [markdown]
# # Scattering
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
